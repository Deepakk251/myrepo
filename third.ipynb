# %%
import nltk

from nltk.stem import PorterStemmer

ps = PorterStemmer()
w= ps.stem("running")
print(w)
# Out:
# run

# %%
import nltk

from nltk.stem import SnowballStemmer

ps = SnowballStemmer("english")
w= ps.stem("running")
print(w)
# Out:
# run

# %%
import nltk

from nltk.stem import LancasterStemmer

ps = LancasterStemmer()
w= ps.stem("running")
print(w)
# Out:
# run

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# True

# %%
import nltk

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("running"))
print(lemmatizer.lemmatize("running",pos='v'))
# Out:
# running
# run

# %%
import nltk

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("better",pos='a'))
print(lemmatizer.lemmatize("better",pos='v'))
# Out:
# good
# better

# %%
import nltk.tokenize

nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize,sent_tokenize

#text = "developer development developed developing"
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
text = "developer development developed developing"
t = word_tokenize(text)
print(t)
ps = PorterStemmer()
ss = SnowballStemmer(language='english')
ls = LancasterStemmer()

print([ps.stem(w) for w in t])
print([ss.stem(w) for w in t])
print([ls.stem(w) for w in t])
# Out:
# ['developer', 'development', 'developed', 'developing']
# ['develop', 'develop', 'develop', 'develop']
# ['develop', 'develop', 'develop', 'develop']
# ['develop', 'develop', 'develop', 'develop']
