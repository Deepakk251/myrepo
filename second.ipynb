# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize

text = "NLTK is powerful. It is used in NLP."
t = word_tokenize(text)
print(t)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# ['NLTK', 'is', 'powerful', '.', 'It', 'is', 'used', 'in', 'NLP', '.']

# %%
from nltk.tokenize import sent_tokenize

text = "NLTK is powerful. It is used in NLP."
t = sent_tokenize(text)
print(t)
# Out:
# ['NLTK is powerful.', 'It is used in NLP.']

# %%
from nltk.tokenize import WhitespaceTokenizer

text = "NLTK is powerful. It is used in NLP."
t = WhitespaceTokenizer()
ti = t.tokenize(text)
print(ti)
# Out:
# ['NLTK', 'is', 'powerful.', 'It', 'is', 'used', 'in', 'NLP.']

# %%
from nltk.tokenize import RegexpTokenizer

text = "NLTK, version 3.8, is powerful."
t = RegexpTokenizer(r'\w')
ti = t.tokenize(text)
print(ti)
# Out:
# ['N', 'L', 'T', 'K', 'v', 'e', 'r', 's', 'i', 'o', 'n', '3', '8', 'i', 's', 'p', 'o', 'w', 'e', 'r', 'f', 'u', 'l']

# %%
from nltk.tokenize import RegexpTokenizer

text = "NLTK, @version 3.8, is #powerful."
t = RegexpTokenizer(r'[@#]\w+')
ti = t.tokenize(text)
print(ti)
# Out:
# ['@version', '#powerful']

# %%
from nltk.tokenize import TreebankWordTokenizer

text = "Don't use spaCy in NLP."
t = TreebankWordTokenizer()
ti = t.tokenize(text)
print(ti)
# Out:
# ['Do', "n't", 'use', 'spaCy', 'in', 'NLP', '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

text = "Don't use spaCy in NLP."
t = TreebankWordTokenizer()
ti = t.tokenize(text)
print(ti)
